# %%
import re
import numpy as np
import pandas as pd
from pandas import Series

from pandas import DataFrame

# %%
file2017 = open('C:\\Users\\Baek GeonJae\\Desktop\\Company Credit\\Data\\2017 Data after preprocessing.csv', encoding='utf-8')
df = pd.read_csv(file2017, decimal=".", thousands=',')
df
# Out:
#              Name 주당배당금/0D2007 주당배당금/0D2007.1    배당금/136300  현금배당금/136310  \
# 0      (주)메타바이오메드         9.85           9.83  2.150440e+08  2.150440e+08
# 1        (주)이건홀딩스        28.04          46.74  6.696060e+08  6.696060e+08
# 2     (주)대성미생물연구소     1,000.00            850  3.230000e+08  3.230000e+08
# 3       에이아이비트(주)            -              -           NaN           NaN
# 4       (주)휴온스글로벌        407.6         521.83  5.172238e+09  4.925941e+09
# ...           ...          ...            ...           ...           ...
# 2057   합성-MSCI선진국          NaN            NaN           NaN           NaN
# 2058     디와이파워(주)       119.94          179.9  1.986453e+09  1.986453e+09
# 2059   마이티 코스피고배당          NaN            NaN           NaN           NaN
# 2060    (주)에스제이그룹          NaN            NaN  7.000000e+08  7.000000e+08
# 2061    데브시스터즈(주)            -              -           NaN           NaN
#
#       당좌비율/203220  매출채권회전율/194120  재고자산회전율1/194080  이익잉여금/118300  베타/280223  \
# 0           84.73            2.61             5.65  7.256676e+09       1.12
# 1           27.47            2.19             6.98  5.407299e+10       0.31
# 2          402.14            6.87             3.63  2.215534e+10       0.27
# 3          126.00            2.22             8.78 -6.162146e+10       0.50
# 4          119.27            7.78            36.83  6.742749e+10       1.71
# ...           ...             ...              ...           ...        ...
# 2057          NaN             NaN              NaN           NaN        NaN
# 2058       205.19            5.80            12.39  3.262174e+10       1.28
# 2059          NaN             NaN              NaN           NaN        NaN
# 2060       188.11           13.98             9.53  1.044214e+10       0.33
# 2061      5078.75            5.57            90.96  2.380518e+10       0.97
#
#       ...  당기순이익/133000  유동비율/193020    매출액/121000  자기자본증가율/191050  \
# 0     ... -3.896803e+09       109.93  4.418587e+10           -9.28
# 1     ...  2.148883e+09        27.47  3.829239e+10            2.10
# 2     ...  1.557554e+09       622.51  2.404337e+10            4.43
# 3     ... -5.560925e+09       126.00  2.211981e+10           19.77
# 4     ...  1.021990e+10       133.13  2.586184e+10            2.06
# ...   ...           ...          ...           ...             ...
# 2057  ...           NaN          NaN           NaN             NaN
# 2058  ...  1.876466e+10       267.86  2.469244e+11           13.73
# 2059  ...           NaN          NaN           NaN             NaN
# 2060  ...  4.501377e+09       261.40  4.546770e+10          120.97
# 2061  ... -1.308236e+10      5084.84  1.714513e+10           -4.28
#
#       매출액(종업원1인당)/195020  1대주주명(지분)/0A2211  종업원수/0A1060 기업규모/0A1070  \
# 0            208423910.0        오석송(21.57)          236        중소기업
# 1            911723550.0        박승준(20.02)           52         대기업
# 2            170520380.0        이동규(32.02)          130        중소기업
# 3            216860900.0      준파투자조합(8.96)          112        중소기업
# 4            304256990.0        윤성태(43.60)          160         대기업
# ...                  ...               ...          ...         ...
# 2057                 NaN               NaN            .          기타
# 2058         646398910.0     디와이(주)(37.69)          398         대기업
# 2059                 NaN               NaN            .          기타
# 2060         622845190.0        이주영(62.25)          100        중소기업
# 2061         107831020.0        이지훈(23.66)           99        중소기업
#
#      KIS 신용평점/0A3010 기말시가총액합계(보통주+우선주)/0D1113
# 0                5.0             7.656048e+10
# 1                5.0             4.656300e+10
# 2                3.0             4.031800e+10
# 3                9.0             5.219229e+10
# 4                3.0             5.510908e+11
# ...              ...                      ...
# 2057             NaN                      NaN
# 2058             2.0             2.097925e+11
# 2059             NaN                      NaN
# 2060             3.0                      NaN
# 2061             5.0             1.631877e+11
#
# [2062 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['Name', '주당배당금/0D2007', '주당배당금/0D2007.1', '배당금/136300', '현금배당금/136310',
#        '당좌비율/203220', '매출채권회전율/194120', '재고자산회전율1/194080', '이익잉여금/118300',
#        '베타/280223', '매출액증가율/091060', '부채비율/193060', '당기순이익/133000',
#        '유동비율/193020', '매출액/121000', '자기자본증가율/191050', '매출액(종업원1인당)/195020',
#        '1대주주명(지분)/0A2211', '종업원수/0A1060', '기업규모/0A1070', 'KIS 신용평점/0A3010',
#        '기말시가총액합계(보통주+우선주)/0D1113'],
#       dtype='object')

# %%
df.head(20)
# Out:
#             Name 주당배당금/0D2007 주당배당금/0D2007.1    배당금/136300  현금배당금/136310  \
# 0     (주)메타바이오메드         9.85           9.83  2.150440e+08  2.150440e+08
# 1       (주)이건홀딩스        28.04          46.74  6.696060e+08  6.696060e+08
# 2    (주)대성미생물연구소     1,000.00            850  3.230000e+08  3.230000e+08
# 3      에이아이비트(주)            -              -           NaN           NaN
# 4      (주)휴온스글로벌        407.6         521.83  5.172238e+09  4.925941e+09
# 5         한국가스공사            -              -           NaN           NaN
# 6       (주)케이티앤지     3,310.85       3,678.72  5.050605e+11  5.050605e+11
# 7         (주)이글벳        19.72          19.37  2.260290e+08  2.260290e+08
# 8        대화제약(주)        48.44          97.03  1.768435e+09  1.768435e+09
# 9     한라아이엠에스(주)        58.84           58.5  6.228870e+08  6.228870e+08
# 10    한스바이오메드(주)        95.53              -  9.417370e+08  9.417370e+08
# 11      (주)제이브이엠        96.08         286.56  1.814196e+09  1.814196e+09
# 12  (주)팬스타엔터프라이즈            -              -           NaN           NaN
# 13      (주)대창솔루션            -              -           NaN           NaN
# 14      (주)에스티큐브            -              -           NaN           NaN
# 15    (주)인지디스플레이        49.98          74.97  2.669306e+09  2.669306e+09
# 16   (주)아즈텍더블유비이           50              -           NaN           NaN
# 17        바이온(주)            -              -           NaN           NaN
# 18        (주)웰크론            -              -           NaN           NaN
# 19   코스맥스비티아이(주)       199.05          99.53  9.558520e+08  9.558520e+08
#
#     당좌비율/203220  매출채권회전율/194120  재고자산회전율1/194080  이익잉여금/118300  베타/280223  \
# 0         84.73            2.61             5.65  7.256676e+09       1.12
# 1         27.47            2.19             6.98  5.407299e+10       0.31
# 2        402.14            6.87             3.63  2.215534e+10       0.27
# 3        126.00            2.22             8.78 -6.162146e+10       0.50
# 4        119.27            7.78            36.83  6.742749e+10       1.71
# 5         83.56            4.50            16.54  4.050034e+12       0.39
# 6        261.99            3.36             3.36  6.001209e+12       0.81
# 7         70.06            5.00             3.42  1.140776e+10       0.73
# 8         45.95            4.83             9.69  4.703183e+10       1.40
# 9        217.41            4.96             5.28  4.795820e+10       0.71
# 10        65.32            3.00             4.01  3.267420e+10       1.22
# 11       152.54            2.58             6.39  8.298014e+10       0.77
# 12        81.24            3.02            11.67 -3.845442e+10       0.37
# 13        19.37            4.02             3.08  1.177049e+10       0.33
# 14       526.26            3.85            21.89 -1.077564e+10       1.06
# 15       125.33            7.46            55.41  8.357480e+10       0.67
# 16       426.45            2.57             1.51  5.758989e+10       0.75
# 17        88.07            2.33            17.33 -3.355138e+10       0.92
# 18        58.36            7.63             4.78  1.164607e+09       0.48
# 19        23.76            3.11            38.26  6.707581e+10       0.83
#
#     ...  당기순이익/133000  유동비율/193020    매출액/121000  자기자본증가율/191050  \
# 0   ... -3.896803e+09       109.93  4.418587e+10           -9.28
# 1   ...  2.148883e+09        27.47  3.829239e+10            2.10
# 2   ...  1.557554e+09       622.51  2.404337e+10            4.43
# 3   ... -5.560925e+09       126.00  2.211981e+10           19.77
# 4   ...  1.021990e+10       133.13  2.586184e+10            2.06
# 5   ... -1.021611e+12       107.52  2.105568e+13          -12.19
# 6   ...  9.748964e+11       321.89  3.000088e+12            8.58
# 7   ...  1.555384e+09       155.54  3.415618e+10            0.81
# 8   ...  1.354125e+10        59.41  8.580223e+10           19.66
# 9   ...  1.392735e+09       246.01  3.457755e+10            5.53
# 10  ...  7.555402e+09       106.49  3.560180e+10           13.94
# 11  ...  1.328420e+10       205.53  9.251396e+10            9.40
# 12  ...  1.796018e+09       109.96  3.352326e+10           39.53
# 13  ... -1.128211e+10        43.91  3.092303e+10           -3.86
# 14  ... -1.079760e+10       556.69  8.460728e+09           -9.20
# 15  ...  4.430028e+09       130.72  8.744624e+10            1.49
# 16  ... -3.645570e+08       675.87  3.443652e+10            0.48
# 17  ... -5.526690e+09        88.52  1.146651e+10           46.20
# 18  ... -1.713644e+09       104.13  9.964693e+10           -2.66
# 19  ...  3.248081e+09        25.14  3.064662e+10            0.37
#
#     매출액(종업원1인당)/195020   1대주주명(지분)/0A2211  종업원수/0A1060 기업규모/0A1070  \
# 0         2.084239e+08         오석송(21.57)          236        중소기업
# 1         9.117236e+08         박승준(20.02)           52         대기업
# 2         1.705204e+08         이동규(32.02)          130        중소기업
# 3         2.168609e+08       준파투자조합(8.96)          112        중소기업
# 4         3.042570e+08         윤성태(43.60)          160         대기업
# 5         5.577662e+09          정부(26.15)     4,213.00          기타
# 6         6.985071e+08       국민연금공단(9.61)     4,075.00         대기업
# 7         3.595388e+08         강태성(14.54)          110        중소기업
# 8         2.472687e+08          고준진(9.90)          364         대기업
# 9         2.401219e+08         지석준(21.84)          175        중소기업
# 10        2.119155e+08         황호찬(23.34)          260        중소기업
# 11        2.829173e+08   한미사이언스(주)(37.42)          320        중소기업
# 12        3.192691e+08         김현겸(10.01)           99        중소기업
# 13        2.454208e+08         박정호(15.93)          157        중소기업
# 14        1.057591e+09  (주)에스티사이언스(12.81)            6        중소기업
# 15        4.912710e+08   인지컨트롤스(주)(25.00)          439         대기업
# 16        3.020748e+08         허재명(22.40)          108        중소기업
# 17        4.246855e+08   더블유글로벌1호조합(9.81)           13        중소기업
# 18        4.722603e+08         이영규(17.09)          222        중소기업
# 19        2.491595e+08         이경수(28.13)          165         대기업
#
#    KIS 신용평점/0A3010 기말시가총액합계(보통주+우선주)/0D1113
# 0              5.0             7.656048e+10
# 1              5.0             4.656300e+10
# 2              3.0             4.031800e+10
# 3              9.0             5.219229e+10
# 4              3.0             5.510908e+11
# 5              6.0             3.927918e+12
# 6              2.0             1.585728e+13
# 7              4.0             6.009244e+10
# 8              4.0             4.510681e+11
# 9              5.0             6.963129e+10
# 10             4.0             1.587115e+11
# 11             2.0             3.633941e+11
# 12             5.0             3.339345e+10
# 13             9.0             2.229500e+10
# 14             5.0             1.535267e+11
# 15             4.0             6.301757e+10
# 16             4.0             4.120587e+10
# 17             7.0             5.886703e+10
# 18             6.0             7.851073e+10
# 19             6.0             3.159690e+11
#
# [20 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2062 entries, 0 to 2061
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Name                      2062 non-null   object
#  1   주당배당금/0D2007              1824 non-null   object
#  2   주당배당금/0D2007.1            1901 non-null   object
#  3   배당금/136300                1082 non-null   float64
#  4   현금배당금/136310              1071 non-null   float64
#  5   당좌비율/203220               2023 non-null   float64
#  6   매출채권회전율/194120            1993 non-null   float64
#  7   재고자산회전율1/194080           1818 non-null   float64
#  8   이익잉여금/118300              2024 non-null   float64
#  9   베타/280223                 1974 non-null   float64
#  10  매출액증가율/091060             1980 non-null   float64
#  11  부채비율/193060               2019 non-null   float64
#  12  당기순이익/133000              2008 non-null   float64
#  13  유동비율/193020               2023 non-null   float64
#  14  매출액/121000                2020 non-null   float64
#  15  자기자본증가율/191050            1983 non-null   float64
#  16  매출액(종업원1인당)/195020        2003 non-null   float64
#  17  1대주주명(지분)/0A2211          2010 non-null   object
#  18  종업원수/0A1060               2062 non-null   object
#  19  기업규모/0A1070               2062 non-null   object
#  20  KIS 신용평점/0A3010           2025 non-null   float64
#  21  기말시가총액합계(보통주+우선주)/0D1113  1901 non-null   float64
# dtypes: float64(16), object(6)
# memory usage: 354.5+ KB

# %%
df = df.set_index('Name')

# %%
df.rename(columns=lambda x: x[:-7], inplace=True)
df
# Out:
#                 주당배당금 주당배당금/0           배당금         현금배당금     당좌비율  매출채권회전율  \
# Name
# (주)메타바이오메드       9.85    9.83  2.150440e+08  2.150440e+08    84.73     2.61
# (주)이건홀딩스        28.04   46.74  6.696060e+08  6.696060e+08    27.47     2.19
# (주)대성미생물연구소  1,000.00     850  3.230000e+08  3.230000e+08   402.14     6.87
# 에이아이비트(주)           -       -           NaN           NaN   126.00     2.22
# (주)휴온스글로벌       407.6  521.83  5.172238e+09  4.925941e+09   119.27     7.78
# ...               ...     ...           ...           ...      ...      ...
# 합성-MSCI선진국        NaN     NaN           NaN           NaN      NaN      NaN
# 디와이파워(주)       119.94   179.9  1.986453e+09  1.986453e+09   205.19     5.80
# 마이티 코스피고배당        NaN     NaN           NaN           NaN      NaN      NaN
# (주)에스제이그룹         NaN     NaN  7.000000e+08  7.000000e+08   188.11    13.98
# 데브시스터즈(주)           -       -           NaN           NaN  5078.75     5.57
#
#              재고자산회전율1         이익잉여금    베타  매출액증가율  ...         당기순이익     유동비율  \
# Name                                               ...
# (주)메타바이오메드       5.65  7.256676e+09  1.12    7.07  ... -3.896803e+09   109.93
# (주)이건홀딩스         6.98  5.407299e+10  0.31  -72.14  ...  2.148883e+09    27.47
# (주)대성미생물연구소      3.63  2.215534e+10  0.27  -21.94  ...  1.557554e+09   622.51
# 에이아이비트(주)        8.78 -6.162146e+10  0.50  -37.29  ... -5.560925e+09   126.00
# (주)휴온스글로벌       36.83  6.742749e+10  1.71  140.78  ...  1.021990e+10   133.13
# ...               ...           ...   ...     ...  ...           ...      ...
# 합성-MSCI선진국        NaN           NaN   NaN     NaN  ...           NaN      NaN
# 디와이파워(주)        12.39  3.262174e+10  1.28   23.64  ...  1.876466e+10   267.86
# 마이티 코스피고배당        NaN           NaN   NaN     NaN  ...           NaN      NaN
# (주)에스제이그룹        9.53  1.044214e+10  0.33   15.70  ...  4.501377e+09   261.40
# 데브시스터즈(주)       90.96  2.380518e+10  0.97   14.13  ... -1.308236e+10  5084.84
#
#                       매출액  자기자본증가율  매출액(종업원1인당)      1대주주명(지분) 종업원수  기업규모  \
# Name
# (주)메타바이오메드   4.418587e+10    -9.28  208423910.0     오석송(21.57)  236  중소기업
# (주)이건홀딩스     3.829239e+10     2.10  911723550.0     박승준(20.02)   52   대기업
# (주)대성미생물연구소  2.404337e+10     4.43  170520380.0     이동규(32.02)  130  중소기업
# 에이아이비트(주)    2.211981e+10    19.77  216860900.0   준파투자조합(8.96)  112  중소기업
# (주)휴온스글로벌    2.586184e+10     2.06  304256990.0     윤성태(43.60)  160   대기업
# ...                   ...      ...          ...            ...  ...   ...
# 합성-MSCI선진국            NaN      NaN          NaN            NaN    .    기타
# 디와이파워(주)     2.469244e+11    13.73  646398910.0  디와이(주)(37.69)  398   대기업
# 마이티 코스피고배당            NaN      NaN          NaN            NaN    .    기타
# (주)에스제이그룹    4.546770e+10   120.97  622845190.0     이주영(62.25)  100  중소기업
# 데브시스터즈(주)    1.714513e+10    -4.28  107831020.0     이지훈(23.66)   99  중소기업
#
#             KIS 신용평점  기말시가총액합계(보통주+우선주)
# Name
# (주)메타바이오메드       5.0       7.656048e+10
# (주)이건홀딩스         5.0       4.656300e+10
# (주)대성미생물연구소      3.0       4.031800e+10
# 에이아이비트(주)        9.0       5.219229e+10
# (주)휴온스글로벌        3.0       5.510908e+11
# ...              ...                ...
# 합성-MSCI선진국       NaN                NaN
# 디와이파워(주)         2.0       2.097925e+11
# 마이티 코스피고배당       NaN                NaN
# (주)에스제이그룹        3.0                NaN
# 데브시스터즈(주)        5.0       1.631877e+11
#
# [2062 rows x 21 columns]

# %%
#Drop the columns don't use

df_1 = df.drop(columns=['주당배당금', '주당배당금/0'])

# %%
df_1.isnull().sum()
# Out:
# 배당금                  980
# 현금배당금                991
# 당좌비율                  39
# 매출채권회전율               69
# 재고자산회전율1             244
# 이익잉여금                 38
# 베타                    88
# 매출액증가율                82
# 부채비율                  43
# 당기순이익                 54
# 유동비율                  39
# 매출액                   42
# 자기자본증가율               79
# 매출액(종업원1인당)           59
# 1대주주명(지분)             52
# 종업원수                   0
# 기업규모                   0
# KIS 신용평점              37
# 기말시가총액합계(보통주+우선주)    161
# dtype: int64

# %%
# repalce object value to float

df_1['베타'] = pd.to_numeric(df_1['베타'],errors = 'coerce')
df_1['종업원수'] = pd.to_numeric(df_1['종업원수'],errors = 'coerce')

# %%
#replace the NaN value to mean

df_1['배당금'] = df_1['배당금'].fillna(df_1['배당금'].mean())
df_1['현금배당금'] = df_1['현금배당금'].fillna(df_1['현금배당금'].mean())
df_1['당좌비율'] = df_1['당좌비율'].fillna(df_1['당좌비율'].mean())
df_1['매출채권회전율'] = df_1['매출채권회전율'].fillna(df_1['매출채권회전율'].mean())
df_1['재고자산회전율1'] = df_1['재고자산회전율1'].fillna(df_1['재고자산회전율1'].mean())
df_1['이익잉여금'] = df_1['이익잉여금'].fillna(df_1['이익잉여금'].mean())
df_1['베타'] = df_1['베타'].fillna(df_1['베타'].mean())
df_1['매출액증가율'] = df_1['매출액증가율'].fillna(df_1['매출액증가율'].mean())
df_1['부채비율'] = df_1['부채비율'].fillna(df_1['부채비율'].mean())
df_1['당기순이익'] = df_1['당기순이익'].fillna(df_1['당기순이익'].mean())
df_1['유동비율'] = df_1['유동비율'].fillna(df_1['유동비율'].mean())
df_1['매출액'] = df_1['매출액'].fillna(df_1['매출액'].mean())
df_1['자기자본증가율'] = df_1['자기자본증가율'].fillna(df_1['자기자본증가율'].mean())
df_1['매출액(종업원1인당)'] = df_1['매출액(종업원1인당)'].fillna(df_1['매출액(종업원1인당)'].mean())
df_1['종업원수'] = df_1['종업원수'].fillna(df_1['종업원수'].mean())
df_1['기말시가총액합계(보통주+우선주)'] = df_1['기말시가총액합계(보통주+우선주)'].fillna(df_1['기말시가총액합계(보통주+우선주)'].mean())

# %%
# replace the independent variant(Compnay Credit) to binary

df_1['KIS 신용평점'] = df_1['KIS 신용평점'].mask(df_1['KIS 신용평점'] > 6, int(0))
df_1['KIS 신용평점'] = df_1['KIS 신용평점'].mask(df_1['KIS 신용평점'] <= 6, int(1))

# %%
# replace the value of compnat size 
# small company & not organize = 0
# big company = 1

df_1['기업규모'].mask(df_1['기업규모'] == '중소기업', float(0) , inplace=True)
df_1['기업규모'].mask(df_1['기업규모'] == '기타', float(0) , inplace=True)
df_1['기업규모'].mask(df_1['기업규모'] == '대기업', float(1) , inplace=True)
df_1['기업규모'] = pd.to_numeric(df_1['기업규모'],errors = 'coerce')

# %%
# sort the 
df_1['1대주주명(지분)'] = df_1['1대주주명(지분)'].str[-6:-1]
df_1['1대주주명(지분)'] = pd.to_numeric(df_1['1대주주명(지분)'],errors = 'coerce')
df_1['1대주주명(지분)'] = df_1['1대주주명(지분)'].fillna(df_1['1대주주명(지분)'].mean())

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2062 entries, (주)메타바이오메드 to 데브시스터즈(주)
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   배당금                2062 non-null   float64
#  1   현금배당금              2062 non-null   float64
#  2   당좌비율               2062 non-null   float64
#  3   매출채권회전율            2062 non-null   float64
#  4   재고자산회전율1           2062 non-null   float64
#  5   이익잉여금              2062 non-null   float64
#  6   베타                 2062 non-null   float64
#  7   매출액증가율             2062 non-null   float64
#  8   부채비율               2062 non-null   float64
#  9   당기순이익              2062 non-null   float64
#  10  유동비율               2062 non-null   float64
#  11  매출액                2062 non-null   float64
#  12  자기자본증가율            2062 non-null   float64
#  13  매출액(종업원1인당)        2062 non-null   float64
#  14  1대주주명(지분)          2062 non-null   float64
#  15  종업원수               2062 non-null   float64
#  16  기업규모               2062 non-null   float64
#  17  KIS 신용평점           2025 non-null   float64
#  18  기말시가총액합계(보통주+우선주)  2062 non-null   float64
# dtypes: float64(19)
# memory usage: 322.2+ KB

# %%
df_1.head(10)
# Out:
#                       배당금         현금배당금    당좌비율  매출채권회전율  재고자산회전율1  \
# Name
# (주)메타바이오메드   2.150440e+08  2.150440e+08   84.73     2.61      5.65
# (주)이건홀딩스     6.696060e+08  6.696060e+08   27.47     2.19      6.98
# (주)대성미생물연구소  3.230000e+08  3.230000e+08  402.14     6.87      3.63
# 에이아이비트(주)    1.656817e+10  1.671659e+10  126.00     2.22      8.78
# (주)휴온스글로벌    5.172238e+09  4.925941e+09  119.27     7.78     36.83
# 한국가스공사       1.656817e+10  1.671659e+10   83.56     4.50     16.54
# (주)케이티앤지     5.050605e+11  5.050605e+11  261.99     3.36      3.36
# (주)이글벳       2.260290e+08  2.260290e+08   70.06     5.00      3.42
# 대화제약(주)      1.768435e+09  1.768435e+09   45.95     4.83      9.69
# 한라아이엠에스(주)   6.228870e+08  6.228870e+08  217.41     4.96      5.28
#
#                     이익잉여금    베타  매출액증가율    부채비율         당기순이익    유동비율  \
# Name
# (주)메타바이오메드   7.256676e+09  1.12    7.07   82.37 -3.896803e+09  109.93
# (주)이건홀딩스     5.407299e+10  0.31  -72.14   23.10  2.148883e+09   27.47
# (주)대성미생물연구소  2.215534e+10  0.27  -21.94   14.81  1.557554e+09  622.51
# 에이아이비트(주)   -6.162146e+10  0.50  -37.29  204.76 -5.560925e+09  126.00
# (주)휴온스글로벌    6.742749e+10  1.71  140.78    2.63  1.021990e+10  133.13
# 한국가스공사       4.050034e+12  0.39    4.35  407.66 -1.021611e+12  107.52
# (주)케이티앤지     6.001209e+12  0.81    1.08   21.51  9.748964e+11  321.89
# (주)이글벳       1.140776e+10  0.73   18.41   55.95  1.555384e+09  155.54
# 대화제약(주)      4.703183e+10  1.40    4.69   93.58  1.354125e+10   59.41
# 한라아이엠에스(주)   4.795820e+10  0.71  -16.95   35.35  1.392735e+09  246.01
#
#                       매출액  자기자본증가율   매출액(종업원1인당)  1대주주명(지분)        종업원수  기업규모  \
# Name
# (주)메타바이오메드   4.418587e+10    -9.28  2.084239e+08  21.570000  236.000000   0.0
# (주)이건홀딩스     3.829239e+10     2.10  9.117236e+08  20.020000   52.000000   1.0
# (주)대성미생물연구소  2.404337e+10     4.43  1.705204e+08  32.020000  130.000000   0.0
# 에이아이비트(주)    2.211981e+10    19.77  2.168609e+08  30.984997  112.000000   0.0
# (주)휴온스글로벌    2.586184e+10     2.06  3.042570e+08  43.600000  160.000000   1.0
# 한국가스공사       2.105568e+13   -12.19  5.577662e+09  26.150000  233.818729   0.0
# (주)케이티앤지     3.000088e+12     8.58  6.985071e+08  30.984997  233.818729   1.0
# (주)이글벳       3.415618e+10     0.81  3.595388e+08  14.540000  110.000000   0.0
# 대화제약(주)      8.580223e+10    19.66  2.472687e+08  30.984997  364.000000   1.0
# 한라아이엠에스(주)   3.457755e+10     5.53  2.401219e+08  21.840000  175.000000   0.0
#
#              KIS 신용평점  기말시가총액합계(보통주+우선주)
# Name
# (주)메타바이오메드        1.0       7.656048e+10
# (주)이건홀딩스          1.0       4.656300e+10
# (주)대성미생물연구소       1.0       4.031800e+10
# 에이아이비트(주)         1.0       5.219229e+10
# (주)휴온스글로벌         1.0       5.510908e+11
# 한국가스공사            1.0       3.927918e+12
# (주)케이티앤지          1.0       1.585728e+13
# (주)이글벳            1.0       6.009244e+10
# 대화제약(주)           1.0       4.510681e+11
# 한라아이엠에스(주)        1.0       6.963129e+10
