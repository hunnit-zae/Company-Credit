# %%
import numpy as np
import pandas as pd
from pandas import Series
from pandas import DataFrame

# %%
file2016 = open('C:\\Users\\Baek GeonJae\\Desktop\\Company Credit\\Data\\2016 Data after preprocessing.csv', encoding='utf-8')
file1 = pd.read_csv(file2016)
file1
# Out:
#              Name 2015주당배당금/0D2007 2016주당배당금/0D2007        배당금/136300  \
# 0      (주)메타바이오메드             9.93             9.85    215,414,000.00
# 1        (주)이건홀딩스            28.04            28.04    401,764,000.00
# 2     (주)대성미생물연구소         1,000.00         1,000.00    380,000,000.00
# 3       에이아이비트(주)                -                -               NaN
# 4       (주)휴온스글로벌           544.85            407.6  3,961,279,000.00
# ...           ...              ...              ...               ...
# 2058   합성-MSCI선진국              NaN              NaN               NaN
# 2059     디와이파워(주)            99.95           119.94  1,324,302,000.00
# 2060   마이티 코스피고배당              NaN              NaN               NaN
# 2061    (주)에스제이그룹              NaN              NaN    500,000,000.00
# 2062    데브시스터즈(주)                -                -               NaN
#
#           현금배당금/136310 당좌비율/203220 매출채권회전율/194120 재고자산회전율1/194080  \
# ...

# %%
file2017 = open('C:\\Users\\Baek GeonJae\\Desktop\\Company Credit\\Data\\2017 Data after preprocessing.csv', encoding='utf-8')
file2 = pd.read_csv(file2017)
file2
# Out:
#        Unnamed: 0   2016/Annual   2017/Annual     2017/Annual.1  \
# 0            Name  주당배당금/0D2007  주당배당금/0D2007        배당금/136300
# 1      (주)메타바이오메드          9.85          9.83    215,044,000.00
# 2        (주)이건홀딩스         28.04         46.74    669,606,000.00
# 3     (주)대성미생물연구소      1,000.00           850    323,000,000.00
# 4       에이아이비트(주)             -             -               NaN
# ...           ...           ...           ...               ...
# 2058   합성-MSCI선진국           NaN           NaN               NaN
# 2059     디와이파워(주)        119.94         179.9  1,986,453,000.00
# 2060   마이티 코스피고배당           NaN           NaN               NaN
# 2061    (주)에스제이그룹           NaN           NaN    700,000,000.00
# 2062    데브시스터즈(주)             -             -               NaN
#
#          2017/Annual.2 2017/Annual.3   2017/Annual.4    2017/Annual.5  \
# 0         현금배당금/136310   당좌비율/203220  매출채권회전율/194120  재고자산회전율1/194080
# ...

# %%
file2018 = open('C:\\Users\\Baek GeonJae\\Desktop\\Company Credit\\Data\\2018 Data after preprocessing.csv', encoding='utf-8')
file3 = pd.read_csv(file2018)
file3
# Out:
#        Unnamed: 0   2017/Annual   2018/Annual     2018/Annual.1  \
# 0            Name  주당배당금/0D2007  주당배당금/0D2007        배당금/136300
# 1      (주)메타바이오메드          9.83          9.78    233,284,000.00
# 2        (주)이건홀딩스         46.74          67.1  1,515,483,000.00
# 3     (주)대성미생물연구소           850            85    323,000,000.00
# 4       에이아이비트(주)             -             -               NaN
# ...           ...           ...           ...               ...
# 2058   합성-MSCI선진국           NaN           NaN               NaN
# 2059     디와이파워(주)         179.9        199.89  2,207,170,000.00
# 2060   마이티 코스피고배당           NaN           NaN               NaN
# 2061    (주)에스제이그룹           NaN           NaN    700,000,000.00
# 2062    데브시스터즈(주)             -             -               NaN
#
#          2018/Annual.2 2018/Annual.3   2018/Annual.4    2018/Annual.5  \
# 0         현금배당금/136310   당좌비율/203220  매출채권회전율/194120  재고자산회전율1/194080
# ...
